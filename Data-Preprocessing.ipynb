# %%
import pandas as pd
# Out:
# C:\Users\sripriya\AppData\Local\Temp\ipykernel_11476\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dataset=pd.read_csv('Placement_Data_Full_Class.csv')

# %%
dataset
# Out:
#      Sno Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 0      1      M   67.00    Others   91.00    Others    Commerce     58.00
# 1      2      M   79.33   Central   78.33    Others     Science     77.48
# 2      3      M   65.00   Central   68.00   Central        Arts     64.00
# 3      4      M   56.00   Central   52.00   Central     Science     52.00
# 4      5      M   85.80   Central   73.60   Central    Commerce     73.30
# ..   ...    ...     ...       ...     ...       ...         ...       ...
# 210  211      M   80.60    Others   82.00    Others    Commerce     77.60
# 211  212      M   58.00    Others   60.00    Others     Science     72.00
# 212  213      M   67.00    Others   67.00    Others    Commerce     73.00
# 213  214      F   74.00    Others   66.00    Others    Commerce     58.00
# 214  215      M   62.00   Central   58.00    Others     Science     53.00
#
#     Degree stream Work exp specialisation  Mba %      status    salary
# 0        Sci&Tech       No         Mkt&HR  58.80      Placed  270000.0
# 1        Sci&Tech      Yes        Mkt&Fin  66.28      Placed  200000.0
# 2       Comm&Mgmt       No        Mkt&Fin  57.80      Placed  250000.0
# 3        Sci&Tech       No         Mkt&HR  59.43  Not Placed       NaN
# 4       Comm&Mgmt       No        Mkt&Fin  55.50      Placed  425000.0
# ..            ...      ...            ...    ...         ...       ...
# 210     Comm&Mgmt       No        Mkt&Fin  74.49      Placed  400000.0
# 211      Sci&Tech       No        Mkt&Fin  53.62      Placed  275000.0
# 212     Comm&Mgmt      Yes        Mkt&Fin  69.72      Placed  295000.0
# 213     Comm&Mgmt       No         Mkt&HR  60.23      Placed  204000.0
# 214     Comm&Mgmt       No         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 14 columns]

# %%
dataset.isnull().sum()
# Out:
# Sno                0
# Gender             0
# 10th %             0
# SSC Board          0
# 12th %             0
# HSC Board          0
# 12th Stream        0
# Degree %           0
# Degree stream      0
# Work exp           0
# specialisation     0
# Mba %              0
# status             0
# salary            67
# dtype: int64

# %%
#1)replace the missing value with central tendency-Mean Median Mode
#2)entire row delete
#3)respective to the problem have to replace the missing values
#4)consider this as a semi supervised, create a model,so that we can predict the missing values.

# %%
dataset.isna().sum()
# Out:
# Sno                0
# Gender             0
# 10th %             0
# SSC Board          0
# 12th %             0
# HSC Board          0
# 12th Stream        0
# Degree %           0
# Degree stream      0
# Work exp           0
# specialisation     0
# Mba %              0
# status             0
# salary            67
# dtype: int64

# %%
dataset["salary"].fillna(0,inplace=True)
# Out:
# C:\Users\sripriya\AppData\Local\Temp\ipykernel_11476\2080798296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["salary"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Sno                0
# Gender             0
# 10th %             0
# SSC Board          0
# 12th %             0
# HSC Board          0
# 12th Stream        0
# Degree %           0
# Degree stream      0
# Work exp           0
# specialisation     0
# Mba %              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      Sno Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 0      1      M   67.00    Others   91.00    Others    Commerce     58.00
# 1      2      M   79.33   Central   78.33    Others     Science     77.48
# 2      3      M   65.00   Central   68.00   Central        Arts     64.00
# 4      5      M   85.80   Central   73.60   Central    Commerce     73.30
# 7      8      M   82.00   Central   64.00   Central     Science     66.00
# ..   ...    ...     ...       ...     ...       ...         ...       ...
# 209  210      M   62.00   Central   72.00   Central    Commerce     65.00
# 210  211      M   80.60    Others   82.00    Others    Commerce     77.60
# 211  212      M   58.00    Others   60.00    Others     Science     72.00
# 212  213      M   67.00    Others   67.00    Others    Commerce     73.00
# 213  214      F   74.00    Others   66.00    Others    Commerce     58.00
#
#     Degree stream Work exp specialisation  Mba %  status    salary
# 0        Sci&Tech       No         Mkt&HR  58.80  Placed  270000.0
# 1        Sci&Tech      Yes        Mkt&Fin  66.28  Placed  200000.0
# 2       Comm&Mgmt       No        Mkt&Fin  57.80  Placed  250000.0
# 4       Comm&Mgmt       No        Mkt&Fin  55.50  Placed  425000.0
# 7        Sci&Tech      Yes        Mkt&Fin  62.14  Placed  252000.0
# ..            ...      ...            ...    ...     ...       ...
# 209     Comm&Mgmt       No        Mkt&Fin  56.49  Placed  216000.0
# 210     Comm&Mgmt       No        Mkt&Fin  74.49  Placed  400000.0
# 211      Sci&Tech       No        Mkt&Fin  53.62  Placed  275000.0
# 212     Comm&Mgmt      Yes        Mkt&Fin  69.72  Placed  295000.0
# 213     Comm&Mgmt       No         Mkt&HR  60.23  Placed  204000.0
#
# [148 rows x 14 columns]

# %%
dataset["salary"].fillna(dataset["salary"].mean(),inplace=True)
# Out:
# C:\Users\sripriya\AppData\Local\Temp\ipykernel_11476\2561448817.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["salary"].fillna(dataset["salary"].mean(),inplace=True)

# %%
dataset
# Out:
#      Sno Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 0      1      M   67.00    Others   91.00    Others    Commerce     58.00
# 1      2      M   79.33   Central   78.33    Others     Science     77.48
# 2      3      M   65.00   Central   68.00   Central        Arts     64.00
# 4      5      M   85.80   Central   73.60   Central    Commerce     73.30
# 7      8      M   82.00   Central   64.00   Central     Science     66.00
# ..   ...    ...     ...       ...     ...       ...         ...       ...
# 209  210      M   62.00   Central   72.00   Central    Commerce     65.00
# 210  211      M   80.60    Others   82.00    Others    Commerce     77.60
# 211  212      M   58.00    Others   60.00    Others     Science     72.00
# 212  213      M   67.00    Others   67.00    Others    Commerce     73.00
# 213  214      F   74.00    Others   66.00    Others    Commerce     58.00
#
#     Degree stream Work exp specialisation  Mba %  status    salary
# 0        Sci&Tech       No         Mkt&HR  58.80  Placed  270000.0
# 1        Sci&Tech      Yes        Mkt&Fin  66.28  Placed  200000.0
# 2       Comm&Mgmt       No        Mkt&Fin  57.80  Placed  250000.0
# 4       Comm&Mgmt       No        Mkt&Fin  55.50  Placed  425000.0
# 7        Sci&Tech      Yes        Mkt&Fin  62.14  Placed  252000.0
# ..            ...      ...            ...    ...     ...       ...
# 209     Comm&Mgmt       No        Mkt&Fin  56.49  Placed  216000.0
# 210     Comm&Mgmt       No        Mkt&Fin  74.49  Placed  400000.0
# 211      Sci&Tech       No        Mkt&Fin  53.62  Placed  275000.0
# 212     Comm&Mgmt      Yes        Mkt&Fin  69.72  Placed  295000.0
# 213     Comm&Mgmt       No         Mkt&HR  60.23  Placed  204000.0
#
# [148 rows x 14 columns]

# %%
def qnanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
       # print(columnName)
        if(dataset[columnName].dtype=='O'):
           # print("qual")
            qual.append(columnName)
        else:
           # print("quan")
            quan.append(columnName)
    return quan, qual

# %%
quan,qual= qnanQual(dataset)

# %%
dataset[quan]
# Out:
#      Sno  10th %  12th %  Degree %  Mba %    salary
# 0      1   67.00   91.00     58.00  58.80  270000.0
# 1      2   79.33   78.33     77.48  66.28  200000.0
# 2      3   65.00   68.00     64.00  57.80  250000.0
# 4      5   85.80   73.60     73.30  55.50  425000.0
# 7      8   82.00   64.00     66.00  62.14  252000.0
# ..   ...     ...     ...       ...    ...       ...
# 209  210   62.00   72.00     65.00  56.49  216000.0
# 210  211   80.60   82.00     77.60  74.49  400000.0
# 211  212   58.00   60.00     72.00  53.62  275000.0
# 212  213   67.00   67.00     73.00  69.72  295000.0
# 213  214   74.00   66.00     58.00  60.23  204000.0
#
# [148 rows x 6 columns]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp= SimpleImputer(missing_values=np.nan,strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])

# %%
df=pd.DataFrame(df,columns=quan)

# %%
df
# Out:
#        Sno  10th %  12th %  Degree %  Mba %    salary
# 0      1.0   67.00   91.00     58.00  58.80  270000.0
# 1      2.0   79.33   78.33     77.48  66.28  200000.0
# 2      3.0   65.00   68.00     64.00  57.80  250000.0
# 3      5.0   85.80   73.60     73.30  55.50  425000.0
# 4      8.0   82.00   64.00     66.00  62.14  252000.0
# ..     ...     ...     ...       ...    ...       ...
# 143  210.0   62.00   72.00     65.00  56.49  216000.0
# 144  211.0   80.60   82.00     77.60  74.49  400000.0
# 145  212.0   58.00   60.00     72.00  53.62  275000.0
# 146  213.0   67.00   67.00     73.00  69.72  295000.0
# 147  214.0   74.00   66.00     58.00  60.23  204000.0
#
# [148 rows x 6 columns]

# %%
imp
# Out:
# SimpleImputer()

# %%
dataset
# Out:
#      Sno Gender  10th % SSC Board  12th % HSC Board 12th Stream  Degree %  \
# 0      1      M   67.00    Others   91.00    Others    Commerce     58.00
# 1      2      M   79.33   Central   78.33    Others     Science     77.48
# 2      3      M   65.00   Central   68.00   Central        Arts     64.00
# 4      5      M   85.80   Central   73.60   Central    Commerce     73.30
# 7      8      M   82.00   Central   64.00   Central     Science     66.00
# ..   ...    ...     ...       ...     ...       ...         ...       ...
# 209  210      M   62.00   Central   72.00   Central    Commerce     65.00
# 210  211      M   80.60    Others   82.00    Others    Commerce     77.60
# 211  212      M   58.00    Others   60.00    Others     Science     72.00
# 212  213      M   67.00    Others   67.00    Others    Commerce     73.00
# 213  214      F   74.00    Others   66.00    Others    Commerce     58.00
#
#     Degree stream Work exp specialisation  Mba %  status    salary
# 0        Sci&Tech       No         Mkt&HR  58.80  Placed  270000.0
# 1        Sci&Tech      Yes        Mkt&Fin  66.28  Placed  200000.0
# 2       Comm&Mgmt       No        Mkt&Fin  57.80  Placed  250000.0
# 4       Comm&Mgmt       No        Mkt&Fin  55.50  Placed  425000.0
# 7        Sci&Tech      Yes        Mkt&Fin  62.14  Placed  252000.0
# ..            ...      ...            ...    ...     ...       ...
# 209     Comm&Mgmt       No        Mkt&Fin  56.49  Placed  216000.0
# 210     Comm&Mgmt       No        Mkt&Fin  74.49  Placed  400000.0
# 211      Sci&Tech       No        Mkt&Fin  53.62  Placed  275000.0
# 212     Comm&Mgmt      Yes        Mkt&Fin  69.72  Placed  295000.0
# 213     Comm&Mgmt       No         Mkt&HR  60.23  Placed  204000.0
#
# [148 rows x 14 columns]
